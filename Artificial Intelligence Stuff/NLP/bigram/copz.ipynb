# %%
import random


class MarkovChain:

    def __init__(self):
        self.memory = {}

    def _learn_key(self, key, value):
        if key not in self.memory:
            self.memory[key] = []

        self.memory[key].append(value)

    def learn(self, text):
        tokens = text.split(" ")
        bigrams = [(tokens[i], tokens[i + 1]) for i in range(0, len(tokens) - 1)]
        for bigram in bigrams:
            self._learn_key(bigram[0], bigram[1])

    def _next(self, current_state):
        next_possible = self.memory.get(current_state)

        if not next_possible:
            next_possible = self.memory.keys()

        return random.sample(next_possible, 1)[0]

    def babble(self, amount, state=''):
        if not amount:
            return state

        next_word = self._next(state)
        return state + ' ' + self.babble(amount - 1, next_word)

with open('datatest.txt', 'r') as myfile:
    data=myfile.read().replace('\n', '')
m = MarkovChain()
m.learn(data)
print(m.memory)
# Out:
# {'A.': [''], '': ['', 'PEMBENTUKAN', '', 'SIDANG-SIDANG', 'bendera', '', 'Peri', '', 'Peri', '', 'Peri', '', 'Peri', '', 'Kesejahteraan', '', 'persatuan2.', '', 'kekeluargaan3.', '', 'keseimbangan4.', '', 'musyawarah5.', '', 'keadilan', '', 'Kebangsaan', '', 'Internasionalisme', '', 'Mufakat', '', 'Kesejahteraan', '', 'Ke-Tuhanan', '', 'Ir.', '', 'Drs.', '', 'Muh.', '', 'Mr.', '', 'Mr.', '', 'Abdulkadir', '', 'K.H.', '', 'K.H.', '', 'Abikusno', '', 'Ke-Tuhanan,', '', '(menurut)', '', 'Persatuan', '', '(dan)', '', '(serta', '', '', 'Pernyataan', '', '', 'Pembukaan', '', '', 'Undang-undang', '', 'AKTIVITAS', '', '', 'semua', '', '', 'dipercepatnya', '', '', 'mencapai', '', '', 'menanamkan', '', '', 'membentuk', '', '', 'mempersatukan', 'Cuo', '', 'PEMBENTUKAN', 'tanggal', '', 'PERBEDAAN', '“', 'Indonesia', 'Kedua', 'Karena', 'Ketegangan', '', 'PERISTIWA', 'kembali', '', 'PERUMUSAN', '(sebagai', '', 'PELAKSANAAN', 'pengeras', 'sambutan'], 'PEMBENTUKAN': ['BPUPKIPada', 'PPKIPada'], 'BPUPKIPada': ['tahun', 'tanggal'], 'tahun': ['1944'], '1944': ['Saipan'], 'Saipan': ['jatuh'], 'jatuh': ['ke'], 'ke': ['tangan', 'Manchuria.', 'pojok', 'luar', 'Bandung.', 'luar', 'Jakarta.', 'Jakarta', 'Rengasdengklok.', 'Jakarta.G.', 'rumah', 'rumah', 'lantai', 'serambi', 'rumah', 'seluruh', 'rumah', 'Jalan', 'seluruh', 'ruangan', 'Jalan'], 'tangan': ['Sekutu.', 'Sukarno', 'Kepala'], 'Sekutu.': ['Demikian', 'Dengan'], 'Demikian': ['halnya'], 'halnya': ['dengan'], 'dengan': ['pasukan', 'dibantu', 'pengibaran', 'pembahasan', 'kewajiban', 'mewujudkan', 'suara', 'anggotanya', 'Jepang', 'anggotanya', 'Jepang,', 'kekuatannya', 'peristiwa', 'janji', 'golongan', 'diliputi', 'tujuan', 'komandannya', 'Ir.', 'Sukarno-Hatta', 'taruhan', 'pihak', 'tiga', 'ini', 'tjara', 'membacakan', 'mengambil', 'disertai', '“Atas', 'ini', 'tjara', 'pihak', 'tertib.', 'berpakaian', 'sikap', 'pembacaan', 'pengibaran', 'bantuan', 'bantuan'], 'pasukan': ['Jepang', 'Sekutu.', 'Sekutu'], 'Jepang': ['di', 'di', 'mulai', 'mengalami', 'di', 'pada', 'dalam', 'mengangkat', 'dapat', 'membentuk', 'telah', 'seraya', 'akan', 'telah', 'telah', 'harus', 'kepada', 'tidak', 'semata-mata', 'tidak', 'ke', 'itu', 'di'], 'di': ['Papua', 'Pasifik', 'kota', 'daerah-daerah', 'Jawa,', 'gedung', 'Singapura', 'Bandung', 'Jawa', 'Jakarta', 'dalam', 'antara', 'dalam', 'dalamnya', 'bawah', 'lingkungan', 'seluruh', 'Dalat,', 'Dalat', 'kota', 'tanah', 'salah', 'Jalan', 'rumahnya,', 'tempat', 'asrama', 'pantai', 'kota', 'dalam', 'Rengasdengklok.', 'Jakarta', 'gedung', 'Rengasdengklok.', 'Jakarta.', 'Jakarta', 'rumah', 'Jalan', 'kantor', 'rumahnya.Sebelum', 'Jawa', 'ruang', 'serambi', 'rumahnya,', 'Jalan', 'kantor', 'sekitar', 'Jl.', 'belakang', 'seluruh', 'tangan', 'Jawa', 'Jalan', 'Jawa'], 'Papua': ['Nugini,'], 'Nugini,': ['Kepulauan'], 'Kepulauan': ['Solomon', 'Marshall,'], 'Solomon': ['dan'], 'dan': ['Kepulauan', 'bayang-bayang', 'Surabaya.', 'Balikpapan.Dalam', 'Mr.', 'Letnan', 'tujuan', 'beradab;3.', 'beranggotakan', 'Sukiman.', 'Supomo.Persidangan', 'Gerakan', 'mahasiswa', 'mempersiapkan', 'dibulatkan', 'kerjasama', 'Chairul', 'Asmara', 'semangat', 'bangsa', 'golongan', 'Pandu', 'mereka', 'golongan', 'seorang', 'Drs.', 'dr.', 'Nagasaki.', 'menyatakan', 'kemauan', 'soal', 'negara', 'hubungan', 'sebaliknya', 'Darwis', 'berkata', 'sudahilah', 'Iwa', 'Wikana,', 'sanggup', 'menunjukkan', 'perkataan', 'Shudanco', 'Drs.', 'Drs.', 'Hatta', 'berkumpul', 'tokoh', 'Drs.', 'Hatta', 'Hatta', 'Tomegoro', 'diharuskan', 'Mr.', 'B.M.', 'Mr', 'dalam', 'dalam', 'disetujui', 'golongan', 'pers,', 'menyiarkannya', 'Nyonopranowo', 'pengeras', 'sebagainya.', 'Muwardi.Lima', 'mereka', 'Moh.', 'mengikatkannya', 'dr.', 'pegawainya', 'Suhandar.', 'surat', 'Undang-undang'], 'Marshall,': ['dipukul'], 'dipukul': ['mundur'], 'mundur': ['oleh'], 'oleh': ['pasukan', 'seorang', 'Toyohito', 'dua', 'Mr.', 'Toyohiko', 'Ir.', 'hikmat', 'sebuah', 'Ir.', 'Panitia', 'lebih', 'Sukarni,', 'B.M.', 'para', 'Saiko', 'pejabat', 'Jenderal', 'PPKI.', 'Sek ...

# %%
m.babble(3,'adalah sebagai')
# Out:
# 'adalah sebagai Wongsonegoro, Mr. Ahmad'
