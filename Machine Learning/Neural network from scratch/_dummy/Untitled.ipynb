# %%
import numpy as np
#import matplotlib.pyplot as plt
#from https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/
import pandas as pd
import csv
import random
import math
import copy

def sig(x): #activation function: sigmoid
    return 1 /(1+(math.e**-x))
def mse(tar,out): #error check (means squared error)
    return ((tar-out)**2)/2
def grad(o,t,h): #gradient descent from output
    return (o-t)*o*(1-o)*h
def grad2():
    return (grad()+grad())*o*(1-o)*h
#dataset = "./datasets/iris.csv"
#desc: 4 input node, 3 output node, 5 hidden layer's node, 1 hidden layer, 20 first weights and 15 second weights
#1st output: Iris-setosa, 2nd output: Iris-versicolor, 3rd output: Iris-virginica

#initializations
a = 0.5 #learning rate
bh = 0.35 #bias for hidden layer
bo = 0.6 #bias for output layer
w1 = [[0.15,0.2],[0.25,0.3]]#np.random.rand(5,4) #weights for input - hidden layer
w2 = [[0.4,0.45],[0.5,0.55]]#np.random.rand(3,5) #weights for hidden layer - output
#w1 = w1[0]
#w2 = w2[0]
print(w1)
print(w2)

testd1 = [0.05,0.1] #test data, will be changed with csv
testd1o = [0.01,0.99] #expected output, will be changed with csv

#testd1.append(1)
#w1.append(bh)
neth = [0,0]
h = [0,0]
neto = [0,0]
o = [0,0]

#forward pass
for i,j in enumerate(neth):
    neth[i] = np.dot(testd1,w1[i])+bh
    h[i] = sig(neth[i])

for i,j in enumerate(neto):
    neto[i] = np.dot(h,w2[i])+bo
    o[i] = sig(neto[i])
    
#error check
#etot = mse(testd1o[0],o[0])+mse(testd1o[1],o[1])+mse(testd1o[2],o[2])
etot = mse(testd1o[0],o[0])+mse(testd1o[1],o[1])
print('error awal: ',etot)
#backward pass
#update w hidden-output UDAH YAKIN BENER
w2t = copy.deepcopy(w2)

for i,k in enumerate(w2): #for the output
    for j,l in enumerate(w2[i]): #for the weight
        w2[i][j] = w2t[i][j]-(a*grad(o[i],testd1o[i],h[j]))
        print('w2['+str(i)+']['+str(j)+']: '+str(w2[i][j]))
print('w2new')
print(w2)
print('w2old')
print(w2t)
#update w input-hidden
#w[0][0] = w[0][0]-(((o[0]-t[0])*o[0]*(1-o[0])*w2t[0][0])+((o[1]-t[1])*o[1]*(1-o[1])*w2t[0][1])+...)*h[0]*(1-h[0])*i[0]*a
#angka dari belakang, i=loop dalem,h=loop luar,h=loop luar,(sigma di bawah), w=luar, dalem
#dalem sigma, bagian w2t[0][0], index pertama berdasar luar
for i,k in enumerate(w1): #for the hidden
    for j,l in enumerate(w1[i]):
        eouth = 0
        for n,m in enumerate(o):
            eouth += grad(o[n],testd1o[n],w2t[n][i])
            print('dEo',n,': ',(o[n]-testd1o[n]))
            print('dOuto',n,': ',o[n]*(1-o[n]))
            print('h',n,': ',w2t[n][j])
            
            print('Eo',n,': ',grad(o[n],testd1o[n],w2t[n][i]))
        print('Etot: ',eouth)
        w1[i][j] = w1[i][j]-(eouth*h[i]*(1-h[i])*testd1[j]*a)
        print('w1['+str(i)+']['+str(j)+']: '+str(w1[i][j]))
        
        
        

#print('w[0][0] = w[0][0]-(((o[0]-t[0])*o[0]*(1-o[0])*w2t[0][0])+((o[1]-t[1])*o[1]*(1-o[1])*w2t[0][1])+...)*h[0]*(1-h[0])*i[0]*a')
        

# w2[2][4] = w2t[2][4]-a*grad(o[2],testd1o[2],h[4])
# w2[2][3] = w2t[2][3]-a*grad(o[2],testd1o[2],h[3])
# w2[2][2] = w2t[2][2]-a*grad(o[2],testd1o[2],h[2])
# w2[2][1] = w2t[2][1]-a*grad(o[2],testd1o[2],h[1])
# w2[2][0] = w2t[2][0]-a*grad(o[2],testd1o[2],h[0])
# w2[1][4] = w2t[1][4]-a*grad(o[1],testd1o[1],h[4])
# w2[1][3] = w2t[1][3]-a*grad(o[1],testd1o[1],h[3])
# w2[1][2] = w2t[1][2]-a*grad(o[1],testd1o[1],h[2])
# w2[1][1] = w2t[1][1]-a*grad(o[1],testd1o[1],h[1])
# w2[1][0] = w2t[1][0]-a*grad(o[1],testd1o[1],h[0])
# w2[0][4] = w2t[0][4]-a*grad(o[0],testd1o[0],h[4])
# w2[0][3] = w2t[0][3]-a*grad(o[0],testd1o[0],h[3])
# w2[0][2] = w2t[0][2]-a*grad(o[0],testd1o[0],h[2])
# w2[0][1] = w2t[0][1]-a*grad(o[0],testd1o[0],h[1])
# w2[0][0] = w2t[0][0]-a*grad(o[0],testd1o[0],h[0])

# #forward pass
# #-for loop to number of first hidden neurons
# neth[0] = np.dot(testd1,w1[:4])+bh
# neth[1] = np.dot(testd1,w1[4:8])+bh
# neth[2] = np.dot(testd1,w1[8:12])+bh
# neth[3] = np.dot(testd1,w1[12:16])+bh
# neth[4] = np.dot(testd1,w1[16:])+bh
# #-for loop to number of first hidden neurons
# h[0] = sig(neth[0])
# h[1] = sig(neth[1])
# h[2] = sig(neth[2])
# h[3] = sig(neth[3])
# h[4] = sig(neth[4])
# #-for loop to number of output neurons
# neto[0] = np.dot(h,w2[:5])+bo
# neto[1] = np.dot(h,w2[5:10])+bo
# neto[2] = np.dot(h,w2[10:])+bo
# #-for loop to number of output neurons
# o[0] = sig(neto[0])
# o[1] = sig(neto[1])
# o[2] = sig(neto[2])

# #error check
# etot = mse(testd1o[0],o[0])+mse(testd1o[1],o[1])+mse(testd1o[2],o[2])

# #backward pass



# print("h1: "+str(h1))
# print("h2: "+str(h2))
# print("h3: "+str(h3))
# print("h4: "+str(h4))
# print("h5: "+str(h5))

#iterasi kedua CUMA TEST

#forward pass
for i,j in enumerate(neth):
    neth[i] = np.dot(testd1,w1[i])+bh
    h[i] = sig(neth[i])

for i,j in enumerate(neto):
    neto[i] = np.dot(h,w2[i])+bo
    o[i] = sig(neto[i])
    
etot = mse(testd1o[0],o[0])+mse(testd1o[1],o[1])
print('error after 1st iteration: ',etot)
# Out:
# [[0.15, 0.2], [0.25, 0.3]]
# [[0.4, 0.45], [0.5, 0.55]]
# error awal:  0.2983711087600027
# w2[0][0]: 0.35891647971788465
# w2[0][1]: 0.4086661860762334
# w2[1][0]: 0.5113012702387375
# w2[1][1]: 0.5613701211079891
# w2new
# [[0.35891647971788465, 0.4086661860762334], [0.5113012702387375, 0.5613701211079891]]
# w2old
# [[0.4, 0.45], [0.5, 0.55]]
# dEo 0 :  0.7413650695523157
# dOuto 0 :  0.18681560180895948
# h 0 :  0.4
# Eo 0 :  0.05539942465142278
# dEo 1 :  -0.21707153467853746
# dOuto 1 :  0.17551005281727122
# h 1 :  0.5
# Eo 1 :  -0.019049118258278118
# Etot:  0.03635030639314466
# w1[0][0]: 0.1497807161327628
# dEo 0 :  0.7413650695523157
# dOuto 0 :  0.18681560180895948
# h 0 :  0.45
# Eo 0 :  0.05539942465142278
# dEo 1 :  -0.21707153467853746
# dOuto 1 :  0.17551005281727122
# h 1 :  0.55
# Eo 1 :  -0.019049118258278118
# Etot:  0.03635030639314466
# w1[0][1]: 0.19956143226552567
# dEo 0 :  0.7413650695523157
# dOuto 0 :  0.18681560180895948
# h 0 :  0.4
# Eo 0 :  0.06232435273285063
# dEo 1 :  -0.21707153467853746
# dOuto 1 :  0.17551005281727122
# h 1 :  0.5
# Eo 1 :  -0.020954030084105933
# Etot:  0.0413703226487447
# w1[1][0]: 0.24975114363236958
# dEo 0 :  0.7413650695523157
# dOuto 0 :  0.18681560180895948
# h 0 :  0.45
# Eo 0 :  0.06232435273285063
# dEo 1 :  -0.21707153467853746
# dOuto 1 :  0.17551005281727122
# h 1 :  0.55
# Eo 1 :  -0.020954030084105933
# Etot:  0.0413703226487447
# w1[1][1]: 0.29950228726473915
# error after 1st iteration:  0.29102777369359933
